# %% [markdown]
# <a href="https://colab.research.google.com/github/davidzheng66/python3/blob/master/opencv/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. [OpenCV](https://opencv.org/)
#
# #2. [Learn OpenCV](https://www.youtube.com/watch?v=WQeoO7MI0Bs)

# %%
import cv2
from google.colab.patches import cv2_imshow

# img = cv2.imread('https://github.com/davidzheng66/python3/blob/master/opencv/fig1.png')
img = cv2.imread('fig1.png')
# cv2.imshow('Output', img)
print(img.shape)
cv2_imshow(img)
cv2.waitKey(1000)

cap = cv2.VideoCapture('test.mp4')
while True:
  success, img = cap.read()
  # cv2.imshow('Video', img)
  cv2_imshow(img)
  if cv2.waitKey(1) & 0xFF == ord('q'):
    break
# Out:
# (396, 576, 3)
# <PIL.Image.Image image mode=RGB size=576x396 at 0x7EFCA4DCCE48>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-bb23c185dc1f> in <module>()
#      13   success, img = cap.read()
#      14   # cv2.imshow('Video', img)
# ---> 15   cv2_imshow(img)
#      16   if cv2.waitKey(1) & 0xFF == ord('q'):
#      17     break
#
# /usr/local/lib/python3.6/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %% [markdown]
# #3. Projects
# * Project 1:
# * Project 2:
# * Project 3:
