# %% [markdown]
# <a href="https://colab.research.google.com/github/davidzheng66/python3/blob/master/pandas/pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x  # this line is not required unless you are in a notebook

# %%
import tensorflow as tf  # now import the tensorflow module
print(tf.version)  # make sure the version is 2.x

# %%
import sys
print(sys.version)

# %%
import platform
print(platform.python_version())
# Out:
# 3.6.9

# %% [markdown]
# # [Python Panda Tutorial - Corey Schafer](https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS)

# %% [markdown]
# ## [1. Getting Started with Data Analysis - Installation and Loading Data](https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS)
# * [Pandas(Panel Data): Python Data Analysis Library](https://pandas.pydata.org/)
# * Install packages:
#  * pip install pandas
#  * pip install jupyterlab
# * [Stack Overflow Annual Developer Survey(Data)](https://insights.stackoverflow.com/survey)

# %%
# !pip install -q sklearn

# %% [markdown]
# $$
# \int_0^\infty x^2dx
# $$

# %%
import pandas as pd # Note: it depends on numpy==1.19.3, it doesn't work with numpy==1.19.4

# %%
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_public.csv') # Note: it needs to use "raw" format
df

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.min_rows', 10)
# pd.get_option('display.min_rows')

# %%
df_schema = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_schema.csv')
df_schema.head()

# %%
df_schema.shape

# %%
df.columns

# %%
df['Hobbyist']

# %%
df['Hobbyist'].value_counts()

# %%
df.loc[0, 'Hobbyist']

# %%
df.loc[0:2, 'Hobbyist':'Employment'] # note: row 2 is not inclusive, but column 'Employment' is inclusive

# %% [markdown]
# ## [2. DataFrame and Series Basics - Selecting Rows and Colums](https://www.youtube.com/watch?v=zmdjNSmRXF4&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=2)

# %%
person = {
    "first": "Corey", 
    "last": "Schafer", 
    "email": "CoreyMSchafer@gmail.com"
}
person

# %%
people = {
    "first": ["Corey"], 
    "last": ["Schafer"], 
    "email": ["CoreyMSchafer@gmail.com"]
}
people

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}
people

# %%
people['email']

# %%
import pandas as pd

df = pd.DataFrame(people)
df

# %%
df['email']

# %%
df.email

# %%
type(df['email'])

# %%
df[['last','email']]

# %%
type(df[['last','email']])

# %%
df.columns

# %%
df.iloc[0:2]

# %%
df.iloc[[0,1],2]

# %%
df.loc[0]

# %%
df.loc[[0,1], ['email','last']]

# %% [markdown]
# ## [3. Indexes - How to Set, Reset, and Use Indexed](https://www.youtube.com/watch?v=W9XjRYFkkyw&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=3)

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}
people

# %%
import pandas as pd
df = pd.DataFrame(people)
df

# %%
df['email']

# %%
df.set_index('email', inplace=True)

# %%
df

# %%
df.index
# Out:
# Index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')

# %%
df.loc['CoreyMSchafer@gmail.com', 'last']

# %%
# df.loc[0] # note: error after seting the index, it needs to use iloc
df.iloc[0]
df
df.reset_index(inplace=True)
df

# %%
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_public.csv', index_col='Respondent')
df.head()

# %%
df.loc[1]

# %%
df_schema = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_schema.csv', index_col='Column')
# df_schema.head()
# df_schema.loc['Hobbyist']
# df_schema.loc['MgrIdiot']
df_schema.loc['MgrIdiot', 'QuestionText']

# %%
df_schema.sort_index(ascending=False, inplace=True)
df_schema

# %% [markdown]
# ## [4. Filtering - Using Conditionals to Filter Rows and Columns](https://www.youtube.com/watch?v=Lw2rlcxScZY&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=4)

# %%
import pandas as pd

people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

df = pd.DataFrame(people)

# %%
filt = (df['last'] == 'Doe') & (df['first'] == 'John')
df[filt]
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt, 'email']

# %%
df.loc[~filt, 'email']

# %%
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_public.csv', index_col='Respondent')

# %%
df_schema = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_schema.csv', index_col='Column')

# %%
high_salary = (df['ConvertedComp'] > 130000)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]

# %%
countries = ['United States', 'Canada', 'Germany', 'India', 'United Kindom']
filt = df['Country'].isin(countries)
df.loc[filt, 'Country']

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageWorkedWith']

# %% [markdown]
# ## [5. Updating Rows and Columns - Modifying Data Within DataFrames](https://www.youtube.com/watch?v=DCDe29sIKcE&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=5)

# %%
import pandas as pd

people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns

# %%
type(df.columns)

# %%
df.columns = ['first_name', 'last_name', 'email']
df

# %%
df.columns = [x.upper() for x in df.columns]
df

# %%
df.columns = df.columns.str.replace(' ', '_')
df

# %%
df.columns = [x.lower() for x in df.columns]
df

# %%
df.rename(columns={'first_name':'first', 'last_name':'last'}, inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith      JohnSmith@email.com

# %%
df.loc[2, ['last','email']] =['Doe', 'JohnDoe@email.com']
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2, 'last'] = 'Smith'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df.at[2, 'last'] = 'Doe'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df[filt]['last'] = 'Smith'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
filt = (df['email'] == 'JohnDoe@email.com')
df.loc[filt, 'last'] = 'Smith'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df['email'] = df['email'].str.lower()
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe        JANEDOE@EMAIL.COM
# 2   John    Smith        JOHNDOE@EMAIL.COM

# %%
df['email'] = df['email'].apply(update_email)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe        JANEDOE@EMAIL.COM
# 2   John    Smith        JOHNDOE@EMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     5     17

# %%
df.applymap(str.lower)
# Out:
#    first     last                    email
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane      doe        janedoe@email.com
# 2   john    smith        johndoe@email.com

# %%
df['first'].map({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: object

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df['first'] = df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})
df
# Out:
#    first     last                    email
# 0  Chris  Schafer  coreymschafer@gmail.com
# 1   Mary      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_public.csv', index_col='Respondent')
df.head()

# %%
df_schema = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)

# %%
df.rename(columns={'ConvertedComp' : 'SalaryUSD'}, inplace=True)
df.head()

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 10138        NaN
# 10139        NaN
# 10140    36432.0
# 10141    65301.0
# 10142    87036.0
# Name: SalaryUSD, Length: 9168, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 10138     No
# 10139    Yes
# 10140    Yes
# 10141    Yes
# 10142    Yes
# Name: Hobbyist, Length: 9168, dtype: object

# %%
df['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 10138    False
# 10139     True
# 10140     True
# 10141     True
# 10142     True
# Name: Hobbyist, Length: 9168, dtype: bool

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 10138     No
# 10139    Yes
# 10140    Yes
# 10141    Yes
# 10142    Yes
# Name: Hobbyist, Length: 9168, dtype: object

# %%
df['Hobbyist']= df['Hobbyist'].map({'Yes':True, 'No':False})

# %%
df['Hobbyist']
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 10138    False
# 10139     True
# 10140     True
# 10141     True
# 10142     True
# Name: Hobbyist, Length: 9168, dtype: bool

# %% [markdown]
# ## [6. Add/Remove Rows and Columns From DataFrames](https://www.youtube.com/watch?v=HQ6XO9eT-fc&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=6)

# %%
import pandas as pd

people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['first'] + ' '+ df['last']
# Out:
# 0    Corey Schafer
# 1         Jane Doe
# 2         John Doe
# dtype: object

# %%
df['full_name'] = df['first'] + ' '+ df['last']
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %%
df.drop(columns=['first', 'last'], inplace=True)
df
# Out:
#                      email      full_name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %%
df.append({'first':'Tony'}, ignore_index=True)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN   Tony      NaN

# %%
people = {
    'first': ['Tony', 'Steve'], 
    'last': ['Stark', 'Rogers'], 
    'email': ['IronMan@avenge.com', 'Cap@avenge.com']
}
df2 = pd.DataFrame(people)
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df.append(df2, ignore_index=True, sort=False)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df = df.append(df2, ignore_index=True, sort=False)
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df.drop(index=4)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3       IronMan@avenge.com            NaN   Tony    Stark

# %%
df.drop(index=df[df['last'] == 'Doe'].index)
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
filt = df['last'] == 'Doe'
df.drop(df[filt].index )
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %% [markdown]
# ## [7. Sorting Data](https://www.youtube.com/watch?v=T11QYVfZoD0&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=7)

# %%
import pandas as pd
people = {
    'first': ['Corey', 'Jane', 'John', 'Adam'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Doe'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', 'A@email.com']
}
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by='last', ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 3   Adam      Doe              A@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df['last'].sort_values()
# Out:
# 3        Doe
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_public.csv', index_col='Respondent')
pd.set_option('display.max_columns', 85)
pd.set_option('display.min_rows', 4)
# df.head()
df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# ...                                            ...      ...
# 10141               I am a developer by profession      Yes
# 10142               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...                                                       ...
# 10141       Less than once a month but more than once per ...
# 10142       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# ...

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)
df[['Country', 'ConvertedComp']].head(10)
# Out:
#                 Country  ConvertedComp
# Respondent
# 7085        Afghanistan        14364.0
# 8149        Afghanistan         1596.0
# 7353        Afghanistan            NaN
# 6417        Afghanistan            NaN
# 3787            Albania       114550.0
# 9270            Albania        74474.0
# 6716            Albania        60000.0
# 2332            Albania        22080.0
# 1954            Albania        11040.0
# 9441            Albania            NaN

# %%
df['ConvertedComp'].nlargest(5)
# Out:
# Respondent
# 2113    2000000.0
# 4083    2000000.0
# 3848    2000000.0
# 2115    2000000.0
# 8988    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(5, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 2113        I am a developer by profession      Yes
# 4083        I am a developer by profession      Yes
# 3848        I am a developer by profession      Yes
# 2115        I am a developer by profession      Yes
# 8988        I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 2113                                  Less than once per year
# 4083                               Once a month or more often
# 3848        Less than once a month but more than once per ...
# 2115        Less than once a month but more than once per ...
# 8988                                                    Never
#
#                                                    OpenSource  \
# Respondent
# 2113        OSS is, on average, of HIGHER quality than pro...
# 4083        OSS is, on average, of HIGHER quality than pro...
# ...

# %% [markdown]
# ## [8. Grouping and Aggregating: Analyzing and Exploring Your Data](https://www.youtube.com/watch?v=txMdrV1Ut64&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=8)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_public.csv', index_col='Respondent')
df_schema = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.min_rows', 4)
# df.head()
df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# ...                                            ...      ...
# 10141               I am a developer by profession      Yes
# 10142               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...                                                       ...
# 10141       Less than once a month but more than once per ...
# 10142       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# ...

# %%
df['ConvertedComp'].head(10)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 56030.0

# %%
df.median()
# Out:
# CompTotal        60000.0
# ConvertedComp    56030.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp  WorkWeekHrs   CodeRevHrs          Age
# count  5.784000e+03   5.776000e+03  6694.000000  5185.000000  8192.000000
# mean   1.086709e+09   1.247194e+05    42.345115     5.103443    30.333777
# std    8.257440e+10   2.799005e+05    27.623079     5.372420     9.071842
# min    0.000000e+00   0.000000e+00     1.000000     0.000000     1.000000
# 25%    2.000000e+04   2.516925e+04    40.000000     2.000000    24.000000
# 50%    6.000000e+04   5.603000e+04    40.000000     4.000000    29.000000
# 75%    1.200000e+05   1.000000e+05    44.000000     6.000000    35.000000
# max    6.280000e+12   2.000000e+06  1012.000000    99.000000    99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 5776

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
#         ...
# 10141    Yes
# 10142    Yes
# Name: Hobbyist, Length: 9168, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    7415
# No     1753
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
#            ...
# 10141     Facebook
# 10142       Reddit
# Name: SocialMedia, Length: 9168, dtype: object

# %%
df_schema.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      1469
# YouTube                     1431
# WhatsApp                    1411
# Facebook                    1403
# Twitter                     1211
# Instagram                    624
# I don't use social media     547
# LinkedIn                     456
# Snapchat                      74
# WeChat 微信                     65
# VK ВКонта́кте                 55
# Weibo 新浪微博                     8
# Youku Tudou 优酷                 4
# Hello                          1
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.167713
# YouTube                     0.163375
# WhatsApp                    0.161091
# Facebook                    0.160178
# Twitter                     0.138258
# Instagram                   0.071241
# I don't use social media    0.062450
# LinkedIn                    0.052061
# Snapchat                    0.008448
# WeChat 微信                   0.007421
# VK ВКонта́кте               0.006279
# Weibo 新浪微博                  0.000913
# Youku Tudou 优酷              0.000457
# Hello                       0.000114
# Name: SocialMedia, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States          2040
# India                   946
#                        ...
# Antigua and Barbuda       1
# Guinea                    1
# Name: Country, Length: 150, dtype: int64

# %%
country_group = df.groupby(['Country'])

# %%
country_group.get_group('United States')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# ...                                    ...      ...
# 10127       I am a developer by profession      Yes
# 10136       I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# ...                                                       ...
# 10127                                                   Never
# 10136                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 13          OSS is, on average, of HIGHER quality than pro...
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# ...                                    ...      ...
# 10127       I am a developer by profession      Yes
# 10136       I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# ...                                                       ...
# 10127                                                   Never
# 10136                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 13          OSS is, on average, of HIGHER quality than pro...
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      540
# Twitter                     389
# Facebook                    275
# YouTube                     237
# I don't use social media    171
# Instagram                   155
# LinkedIn                     94
# WhatsApp                     48
# Snapchat                     34
# WeChat 微信                    11
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().head(10)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    2
#              Instagram                   1
#              YouTube                     1
# Albania      Facebook                    3
#              LinkedIn                    2
#              I don't use social media    1
#              Twitter                     1
#              YouTube                     1
# Algeria      Facebook                    8
#              YouTube                     5
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts(normalize=True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.609375
# YouTube                     0.156250
# Weibo 新浪微博                  0.109375
# I don't use social media    0.031250
# LinkedIn                    0.031250
# Facebook                    0.015625
# Instagram                   0.015625
# Reddit                      0.015625
# VK ВКонта́кте               0.015625
# Name: SocialMedia, dtype: float64

# %%
country_group['ConvertedComp'].median().loc['United States']
# Out:
# 110000.0

# %%
country_group['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     73284.500000
# mean      133342.027344
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 980

# %%
country_group['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-f7ba1f4b2daa> in <module>()
# ----> 1 country_group['LanguageWorkedWith'].str.contains('Python').sum()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     702
#     703         raise AttributeError(
# --> 704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#     706
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan    0
# Albania        1
#               ..
# Yemen          1
# Zimbabwe       4
# Name: LanguageWorkedWith, Length: 150, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States          2040
# India                   946
#                        ...
# Antigua and Barbuda       1
# Guinea                    1
# Name: Country, Length: 150, dtype: int64

# %%
country_uses_python = country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan    0
# Albania        1
#               ..
# Yemen          1
# Zimbabwe       4
# Name: LanguageWorkedWith, Length: 150, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                      Country  LanguageWorkedWith
# United States           2040                 980
# India                    946                 342
# ...                      ...                 ...
# Antigua and Barbuda        1                   0
# Guinea                     1                   1
#
# [150 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                      NumRespondents  NumKnowsPython
# United States                  2040             980
# India                           946             342
# ...                             ...             ...
# Antigua and Barbuda               1               0
# Guinea                            1               1
#
# [150 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                      NumRespondents  NumKnowsPython  PctKnowsPython
# United States                  2040             980       48.039216
# India                           946             342       36.152220
# ...                             ...             ...             ...
# Antigua and Barbuda               1               0        0.000000
# Guinea                            1               1      100.000000
#
# [150 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False)
# Out:
#          NumRespondents  NumKnowsPython  PctKnowsPython
# Guinea                1               1           100.0
# Rwanda                1               1           100.0
# ...                 ...             ...             ...
# Kuwait                1               0             0.0
# Bolivia               2               0             0.0
#
# [150 rows x 3 columns]

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    32.00
# NumKnowsPython    18.00
# PctKnowsPython    56.25
# Name: Japan, dtype: float64

# %% [markdown]
# ## [9. Cleaning Data - Casting Datatypes and Handling Missing Values](https://www.youtube.com/watch?v=KdmPHEnPJPs&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=9)

# %%
import pandas as pd
import numpy as np
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how='any')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='columns', how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df.dropna(axis='columns', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how='any', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how='all', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('Missing')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  Missing       36
# 4  Missing  Missing                  Missing  Missing
# 5  Missing  Missing      Anonymous@email.com  Missing
# 6  Missing  Missing                  Missing  Missing

# %%
df.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-f17fc7aadc36> in <module>()
# ----> 1 df['age'].mean()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11473             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11474         return self._reduce(
# > 11475             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11476         )
#   11477
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4247                 )
#    4248             with np.errstate(all="ignore"):
# -> 4249                 return op(delegate, skipna=skipna, **kwds)
#    4250
#    4251     def _reindex_indexer(self, new_index, indexer, copy):
#
# ...

# %%
type(np.nan)
# Out:
# float

# %%
df['age'] = df['age'].astype(float)

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# 46.75

# %%
na_vals =['NA', 'Missing']
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
df_schema = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.min_rows', 4)
# df.head()
df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# ...                                            ...      ...
# 10141               I am a developer by profession      Yes
# 10142               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...                                                       ...
# 10141       Less than once a month but more than once per ...
# 10142       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-14e5d2cf29c5> in <module>()
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '29', '27', '11', '18', '38', '23',
#        '24', '34', '21', '37', '22', '39', '32', '31', '36', '41', '50',
#        '44', '45', '33', '48', '46', '43', 'More than 50 years', '42',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '29', '27', '11', '18', '38', '23', '24', '34', '21',
#        '37', '22', '39', '32', '31', '36', '41', '50', '44', '45', '33',
#        '48', '46', '43', 51, '42', '47', '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCode'].mean()
# Out:
# 11.63949394939494

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %% [markdown]
# ## [10. Working with Dates and Time Series Data](https://www.youtube.com/watch?v=UFuo7EHI8zc&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=10)

# %% [markdown]
# * [Datetime Formatting Codes](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior)
# * [Pandas Date Offset Codes](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects)

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/ETH_1h.csv')
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.loc[0, 'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-55e7fa569c9a> in <module>()
# ----> 1 df.loc[0, 'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2058         try:
# -> 2059             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2060             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-b9c6864122be> in <module>()
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %I-%p')
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """Entry point for launching an IPython kernel.
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['DayOfWeek'] = df['Date'].dt.day_name()
df
# Out:
#                      Date  Symbol    Open  ...   Close      Volume  DayOfWeek
# 0     2020-03-13 20:00:00  ETHUSD  129.94  ...  128.71  1940673.93     Friday
# 1     2020-03-13 19:00:00  ETHUSD  119.51  ...  129.94  7579741.09     Friday
# 2     2020-03-13 18:00:00  ETHUSD  124.47  ...  119.51  4898735.81     Friday
# 3     2020-03-13 17:00:00  ETHUSD  124.08  ...  124.47  2753450.92     Friday
# 4     2020-03-13 16:00:00  ETHUSD  124.85  ...  124.08  4461424.71     Friday
# ...                   ...     ...     ...  ...     ...         ...        ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  ...  272.57  1500282.55   Saturday
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  ...  265.74  1702536.85   Saturday
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  ...  268.79  3010787.99   Saturday
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  ...  274.83   824362.87   Saturday
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  ...  275.01   679358.87   Saturday
#
# [23674 rows x 8 columns]

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df['Date'] >= '2020')
df.loc[filt]
# Out:
#                     Date  Symbol    Open  ...   Close      Volume  DayOfWeek
# 0    2020-03-13 20:00:00  ETHUSD  129.94  ...  128.71  1940673.93     Friday
# 1    2020-03-13 19:00:00  ETHUSD  119.51  ...  129.94  7579741.09     Friday
# 2    2020-03-13 18:00:00  ETHUSD  124.47  ...  119.51  4898735.81     Friday
# 3    2020-03-13 17:00:00  ETHUSD  124.08  ...  124.47  2753450.92     Friday
# 4    2020-03-13 16:00:00  ETHUSD  124.85  ...  124.08  4461424.71     Friday
# ...                  ...     ...     ...  ...     ...         ...        ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  ...  129.56   702786.82  Wednesday
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  ...  129.57   496704.23  Wednesday
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  ...  130.37   396315.72  Wednesday
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  ...  130.14   635419.40  Wednesday
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  ...  128.34   245119.91  Wednesday
#
# [1749 rows x 8 columns]

# %%
filt = (df['Date'] >= '2019') & (df['Date'] < '2020')
df.loc[filt]
# Out:
#                      Date  Symbol    Open  ...   Close      Volume  DayOfWeek
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  ...  128.54   440678.91    Tuesday
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  ...  128.33   554646.02    Tuesday
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  ...  128.38   350155.69    Tuesday
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  ...  127.86   428183.38    Tuesday
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  ...  127.84  1169847.84    Tuesday
# ...                   ...     ...     ...  ...     ...         ...        ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  ...  131.96  2791135.37    Tuesday
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  ...  130.75   503732.63    Tuesday
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  ...  130.06   838183.43    Tuesday
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  ...  130.79   434917.99    Tuesday
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  ...  131.62  1067136.21    Tuesday
#
# [8760 rows x 8 columns]

# %%
filt = (df['Date'] >= pd.to_datetime('2019-01-01')) & (df['Date'] < pd.to_datetime('2020-01-01'))
df.loc[filt]
# Out:
#                      Date  Symbol    Open  ...   Close      Volume  DayOfWeek
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  ...  128.54   440678.91    Tuesday
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  ...  128.33   554646.02    Tuesday
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  ...  128.38   350155.69    Tuesday
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  ...  127.86   428183.38    Tuesday
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  ...  127.84  1169847.84    Tuesday
# ...                   ...     ...     ...  ...     ...         ...        ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  ...  131.96  2791135.37    Tuesday
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  ...  130.75   503732.63    Tuesday
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  ...  130.06   838183.43    Tuesday
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  ...  130.79   434917.99    Tuesday
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  ...  131.62  1067136.21    Tuesday
#
# [8760 rows x 8 columns]

# %%
df.set_index('Date') # note: error
df
# df.reset_index()
# Out:
#                      Symbol    Open    High  ...   Close      Volume  DayOfWeek
# Date                                         ...
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  ...  128.71  1940673.93     Friday
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  ...  129.94  7579741.09     Friday
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  ...  119.51  4898735.81     Friday
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  ...  124.47  2753450.92     Friday
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  ...  124.08  4461424.71     Friday
# ...                     ...     ...     ...  ...     ...         ...        ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  ...  272.57  1500282.55   Saturday
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  ...  265.74  1702536.85   Saturday
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  ...  268.79  3010787.99   Saturday
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  ...  274.83   824362.87   Saturday
# ...

# %%
df['2019']
# Out:
#                      Symbol    Open    High  ...   Close      Volume  DayOfWeek
# Date                                         ...
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  ...  128.54   440678.91    Tuesday
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  ...  128.33   554646.02    Tuesday
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  ...  128.38   350155.69    Tuesday
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  ...  127.86   428183.38    Tuesday
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  ...  127.84  1169847.84    Tuesday
# ...                     ...     ...     ...  ...     ...         ...        ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  ...  131.96  2791135.37    Tuesday
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  ...  130.75   503732.63    Tuesday
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  ...  130.06   838183.43    Tuesday
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  ...  130.79   434917.99    Tuesday
# ...

# %%
df['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High  ...   Close      Volume  DayOfWeek
# Date                                         ...
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  ...  217.31  1927939.88   Saturday
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  ...  223.35   535998.57   Saturday
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  ...  223.48   561158.03   Saturday
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  ...  224.63   511648.65   Saturday
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  ...  225.31  1250856.20   Saturday
# ...                     ...     ...     ...  ...     ...         ...        ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  ...  129.56   702786.82  Wednesday
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  ...  129.57   496704.23  Wednesday
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  ...  130.37   396315.72  Wednesday
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  ...  130.14   635419.40  Wednesday
# ...

# %%
df['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.16559027777814

# %%
df['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
highs = df['High'].resample('D').max()
highs
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
highs.plot()

# %%
df.resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
df.resample('W').agg({'Close':'mean', 'High':'max', 'Low':'min', 'Volume':'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %% [markdown]
# ## [11. Reading/Writing Data to Different Sources - Excel, JSON, SQL](https://www.youtube.com/watch?v=N6hyN6BW6ao&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=11)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_public.csv', index_col='Respondent')
df_schema = pd.read_csv('https://raw.githubusercontent.com/davidzheng66/python3/master/panda/data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.min_rows', 4)
# df.head()
df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# ...                                            ...      ...
# 10141               I am a developer by profession      Yes
# 10142               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...                                                       ...
# 10141       Less than once a month but more than once per ...
# 10142       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# ...

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
india_df.to_csv('sample_data/modified.csv')

# %%
india_df.to_csv('sample_data/modified.tsv', sep='\t')

# %%
tsv = pd.read_csv('sample_data/modified.tsv', sep='\t')
tsv
# Out:
#      Respondent                      MainBranch Hobbyist  \
# 0             8     I code primarily as a hobby      Yes
# 1            10  I am a developer by profession      Yes
# ..          ...                             ...      ...
# 944       10133  I am a developer by profession      Yes
# 945       10138  I am a developer by profession       No
#
#                     OpenSourcer  \
# 0       Less than once per year
# 1    Once a month or more often
# ..                          ...
# 944                       Never
# 945  Once a month or more often
#
#                                             OpenSource  \
# 0    OSS is, on average, of HIGHER quality than pro...
# 1    OSS is, on average, of HIGHER quality than pro...
# ..                                                 ...
# 944  OSS is, on average, of HIGHER quality than pro...
# 945  OSS is, on average, of HIGHER quality than pro...
#
#                              Employment Country Student  \
# ...

# %% [markdown]
# * pip install xlwt openxl xlrd

# %%
india_df.to_excel('sample_data/modified.xlsx')

# %%
excel = pd.read_excel('sample_data/modified.xlsx', index_col='Respondent')
excel
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 8              I code primarily as a hobby      Yes
# 10          I am a developer by profession      Yes
# ...                                    ...      ...
# 10133       I am a developer by profession      Yes
# 10138       I am a developer by profession       No
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# ...                                ...
# 10133                            Never
# 10138       Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 10133       OSS is, on average, of HIGHER quality than pro...
# ...

# %%
india_df.to_json('sample_data/modified.json')

# %%
india_df.to_json('sample_data/modified.json', orient='records', lines=True)

# %%
json = pd.read_json('sample_data/modified.json', orient='records', lines=True)
json
# Out:
#                          MainBranch Hobbyist                 OpenSourcer  \
# 0       I code primarily as a hobby      Yes     Less than once per year
# 1    I am a developer by profession      Yes  Once a month or more often
# ..                              ...      ...                         ...
# 944  I am a developer by profession      Yes                       Never
# 945  I am a developer by profession       No  Once a month or more often
#
#                                             OpenSource  \
# 0    OSS is, on average, of HIGHER quality than pro...
# 1    OSS is, on average, of HIGHER quality than pro...
# ..                                                 ...
# 944  OSS is, on average, of HIGHER quality than pro...
# 945  OSS is, on average, of HIGHER quality than pro...
#
#                              Employment Country Student  \
# 0    Not employed, but looking for work   India    None
# 1                    Employed full-time   India      No
# ...

# %% [markdown]
# * pip install SQLAlchemy
# * pip install psycopg2-binary

# %%
# !pip install psycopg2-binary
# Out:
# ...
#      |████████████████████████████████| 3.0MB 5.7MB/s
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
india_df.to_sql('sample_table', engine, if_exists='replace')

# %%
sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')

# %%
sql_df = pd.read_sql('SELECT * FROM sample_table', engine, index_col='Respondent')

# %%
posts_df = pd.read_json('url')

# %% [markdown]
# # [Extracting Financials from Yahoo Finance with Python - Python for Finance](https://www.youtube.com/watch?v=1aqqw4fuBB0)

# %%
import pandas as pd

# %%
profile = pd.read_html('https://finance.yahoo.com/quote/AAPL/profile?=AAPL')
print('1:\n', type(profile))
print('2:\n', profile)
print('3:\n', type(profile[0]))
print('4:\n', profile[0])
# Out:
# 1:
#  <class 'list'>
# 2:
#  [                      Name  ... Year Born
# 0      Mr. Timothy D. Cook  ...    1961.0
# 1         Mr. Luca Maestri  ...    1964.0
# 2  Mr. Jeffrey E. Williams  ...    1964.0
# 3   Ms. Katherine L. Adams  ...    1964.0
# 4      Ms. Deirdre O'Brien  ...    1967.0
# 5          Mr. Chris Kondo  ...       NaN
# 6         Mr. James Wilson  ...       NaN
# 7           Ms. Mary Demby  ...       NaN
# 8         Ms. Nancy Paxton  ...       NaN
# 9         Mr. Greg Joswiak  ...       NaN
#
# [10 rows x 5 columns]]
# 3:
#  <class 'pandas.core.frame.DataFrame'>
# 4:
#                        Name  ... Year Born
# 0      Mr. Timothy D. Cook  ...    1961.0
# 1         Mr. Luca Maestri  ...    1964.0
# 2  Mr. Jeffrey E. Williams  ...    1964.0
# 3   Ms. Katherine L. Adams  ...    1964.0
# 4      Ms. Deirdre O'Brien  ...    1967.0
# 5          Mr. Chris Kondo  ...       NaN
# 6         Mr. James Wilson  ...       NaN
# 7           Ms. Mary Demby  ...       NaN
# ...

# %%
companies = ['AAPL', 'MSFT']
index = 0;
for company in companies:
  statistics = pd.read_html(f'https://finance.yahoo.com/quote/{company}/key-statistics?p={company}')
  # print('1:\n', len(statistics))
  print('2:\n', statistics[2])

  print('index = ', index)

  statistics[2].to_excel('share_staticstics_' + str(index) + '.xlsx') # Save it to a excel file
 
  index = index + 1
  # ++index

# %% [markdown]
# # [Python for Finance Stock Data with Pandas and NumPy](https://www.youtube.com/watch?v=DOHg16zcUCc)

# %%
from pandas_datareader import data
from pandas_datareader._utils import RemoteDataError
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime

start_date = '2019-12-20'
end_date = str(datetime.now().strftime('%Y-%m-%d'))

uk_stock = 'UU.L'
usa_stock = 'AMZN'

def get_stats(stock_data):
  return {
      'last': np.mean(stock_data.tail(1)),
      'short mean': np.mean(stock_data.tail(20)),
      'long mean': np.mean(stock_data.tail(200)),
      'short_rolling': stock_data.rolling(window=20).mean(),
      'long_rolling': stock_data.rolling(window=200).mean(),
  }

def clean_data(stock_data, col):
  weekdays = pd.date_range(start=start_date, end=end_date)
  clean_data = stock_data[col].reindex(weekdays)
  return clean_data.fillna(method='ffill')

def create_plot(stock_data, ticker):
  stats = get_stats(stock_data)

  plt.style.use('dark_background')
  plt.subplots(figsize=(12,8))

  plt.plot(stock_data, label=ticker)
  plt.plot(stats['short_rolling'], label='20 days rolling mean')
  plt.plot(stats['long_rolling'], label='200 days rolling mean')
  plt.xlabel('Date')
  plt.ylabel('Adj Close (p)')
  plt.legend()
  plt.title('Stock Price Over Time')
  plt.style

  plt.show()

def get_data(ticker):
  try:
    stock_data = data.DataReader(ticker, 'yahoo', start_date, end_date)
    # print('\nticker = ', ticker, stock_data)
    adj_close = (clean_data(stock_data, 'Adj Close'))
    # print(get_stats(adj_close))
    create_plot(adj_close, ticker)
  except RemoteDataError:
    print('No data found for {t}'.formart(t=ticker))

# get_data(uk_stock)
get_data(usa_stock)
